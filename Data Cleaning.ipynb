# %% [markdown]
# # Cleaning small roads

# %%
import numpy as np
import pandas as pd
import json
import keplergl
import networkx as nx
from directed_road_network import DirectedRoadGraphGenerator

# %%
linkData = pd.read_csv("data/linkData-TokyoArea-v2.csv")
leftovers = linkData.loc[((linkData.roadType == 'unclassified') | (linkData.roadType == 'residential') | (linkData.roadType == 'living_street') | (linkData.roadType == 'pedestrian'))]
leftovers
# Out:
# /Users/s_araki/.pyenv/versions/3.6.5/envs/geoanalysis/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (6,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#        type         id                                              nodes  \
# 67      way    4848943  [31254395, 6114579097, 1105125598, 1105125100,...
# 69      way    4849049                 [499185617, 6114407385, 499185467]
# 122     way    4857047  [31330006, 31330057, 6439922815, 31330058, 195...
# 158     way    5170998                               [35926493, 35926496]
# 159     way    5170999  [35926495, 35926500, 35926501, 6877559285, 687...
# ...     ...        ...                                                ...
# 781035  way  812626290                           [1391658116, 7590140392]
# 781036  way  812626291               [7590140394, 7590140393, 1615202001]
# 781037  way  812728992               [2030079963, 7591153650, 7591153651]
# 781038  way  812728998               [3724132549, 3724132548, 3724132547]
# 781039  way  812729001                           [7591165588, 7591165589]
#
#             roadType roadName oneWay speedLimit roadWidth
# 67      unclassified      NaN    yes        NaN       NaN
# 69      unclassified      NaN    yes         30       NaN
# 122     unclassified      NaN    yes        NaN       NaN
# 158     unclassified      NaN    NaN        NaN       NaN
# 159     unclassified      NaN    yes        NaN       NaN
# ...              ...      ...    ...        ...       ...
# 781035   residential      NaN    NaN        NaN       NaN
# 781036   residential      NaN    NaN        NaN       NaN
# 781037   residential      NaN    NaN        NaN       NaN
# 781038   residential      NaN    NaN        NaN       NaN
# 781039   residential      NaN    NaN        NaN       NaN
#
# [689776 rows x 8 columns]

# %% [markdown]
# ## What is the distribution of the road types?

# %%
linkData.groupby('roadType').agg('count').id / linkData.shape[0]
# Out:
# roadType
# living_street     0.007662
# motorway          0.005427
# motorway_link     0.005461
# pedestrian        0.011131
# primary           0.014076
# primary_link      0.001172
# residential       0.524599
# road              0.000563
# secondary         0.011291
# secondary_link    0.000484
# tertiary          0.064568
# tertiary_link     0.000769
# trunk             0.011296
# trunk_link        0.001741
# unclassified      0.339759
# Name: id, dtype: float64

# %% [markdown]
# Seems like there are a lot of small roads (residential and unclassified) occupying roughly 80% of the edges

# %% [markdown]
# ## How much data are missing on each road type?

# %%
leftovers.loc[leftovers.roadType == 'unclassified'].isnull().sum() / leftovers.shape[0]
# Out:
# type          0.000000
# id            0.000000
# nodes         0.000000
# roadType      0.000000
# roadName      0.379661
# oneWay        0.358725
# speedLimit    0.379391
# roadWidth     0.384035
# dtype: float64

# %%
leftovers.loc[leftovers.roadType == 'residential'].isnull().sum() / leftovers.shape[0]
# Out:
# type          0.000000
# id            0.000000
# nodes         0.000000
# roadType      0.000000
# roadName      0.591791
# oneWay        0.568345
# speedLimit    0.589477
# roadWidth     0.592950
# dtype: float64

# %%
leftovers.loc[leftovers.roadType == 'living_street'].isnull().sum() / leftovers.shape[0]
# Out:
# type          0.000000
# id            0.000000
# nodes         0.000000
# roadType      0.000000
# roadName      0.008659
# oneWay        0.007468
# speedLimit    0.008630
# roadWidth     0.008630
# dtype: float64

# %%
leftovers.loc[leftovers.roadType == 'pedestrian'].isnull().sum() / leftovers.shape[0]
# Out:
# type          0.000000
# id            0.000000
# nodes         0.000000
# roadType      0.000000
# roadName      0.011782
# oneWay        0.012037
# speedLimit    0.012600
# roadWidth     0.012477
# dtype: float64

# %% [markdown]
# ## How to decide what to fill the missing values with?

# %%
leftovers.loc[leftovers.roadType == 'unclassified'].oneWay.mode
# Out:
# <bound method Series.mode of 67        yes
# 69        yes
# 122       yes
# 158       NaN
# 159       yes
#          ...
# 781002    NaN
# 781015    yes
# 781018     no
# 781028    NaN
# 781029    NaN
# Name: oneWay, Length: 265365, dtype: object>

# %%
leftovers.loc[leftovers.roadType == 'unclassified'].speedLimit.dropna().max
# Out:
# <bound method Series.max of 69        30
# 259       30
# 260       40
# 320       30
# 335       20
#           ..
# 779649    30
# 779650    30
# 780675    30
# 780850    30
# 780851    30
# Name: speedLimit, Length: 3670, dtype: object>

# %%
linkData.nodes.map(lambda node_list: set(node_list) & node_set)
# Out:
#        type         id                                              nodes  \
# 0       way    4847506  [31236733, 621545916, 621545917, 31236732, 183...
# 1       way    4847507  [31300417, 31300416, 31300384, 3799099877, 498...
# 2       way    4847509  [31236654, 2805815266, 31236651, 2805815274, 3...
# 3       way    4847513                           [1832774262, 1832774263]
# 4       way    4847514  [31252838, 573283112, 31252812, 1876066967, 31...
# ...     ...        ...                                                ...
# 781035  way  812626290                           [1391658116, 7590140392]
# 781036  way  812626291               [7590140394, 7590140393, 1615202001]
# 781037  way  812728992               [2030079963, 7591153650, 7591153651]
# 781038  way  812728998               [3724132549, 3724132548, 3724132547]
# 781039  way  812729001                           [7591165588, 7591165589]
#
#              roadType    roadName oneWay speedLimit roadWidth
# 0            motorway  首都高速11号台場線    yes        NaN       NaN
# 1            motorway     首都高速湾岸線    yes         60       NaN
# 2       motorway_link         NaN    yes        NaN       NaN
# 3            tertiary         NaN    yes        NaN       NaN
# 4            tertiary         NaN    yes        NaN       NaN
# ...               ...         ...    ...        ...       ...
# 781035    residential         NaN    NaN        NaN       NaN
# 781036    residential         NaN    NaN        NaN       NaN
# 781037    residential         NaN    NaN        NaN       NaN
# 781038    residential         NaN    NaN        NaN       NaN
# 781039    residential         NaN    NaN        NaN       NaN
#
# [781040 rows x 8 columns]

# %% [markdown]
# ## Filter out the nodes and edges

# %%
node_data = pd.read_csv("data/leftover_nodes_v1.csv")
node_data
# Out:
#          Unnamed: 0          id        lat         lon  \
# 0             42287  1456908236  35.608371  139.239738
# 1             42288  1456908266  35.608469  139.241025
# 2             42289  1456908343  35.608457  139.241306
# 3             42290  1456908374  35.608478  139.241423
# 4             42291  1456908461  35.608547  139.241728
# ...             ...         ...        ...         ...
# 1175378     3694804  6502211476  35.571015  139.671924
# 1175379     3694805  6502211477  35.571014  139.671329
# 1175380     3694806  6502211688  35.570163  139.672337
# 1175381     3694807  6502211693  35.569847  139.671568
# 1175382     3694808  6502211701  35.570027  139.671491
#
#                                      thisPoint   elevation
# 0               POINT (139.2397382 35.6083708)  415.190002
# 1               POINT (139.2410253 35.6084687)  393.260010
# 2               POINT (139.2413057 35.6084568)  388.769989
# 3               POINT (139.2414228 35.6084781)  386.750000
# 4        POINT (139.2417278 35.60854699999999)  379.260010
# ...                                        ...         ...
# 1175378         POINT (139.6719244 35.5710154)    7.800000
# 1175379  POINT (139.6713289 35.57101420000001)    5.350000
# 1175380  POINT (139.6723373 35.57016289999999)    7.670000
# 1175381         POINT (139.6715677 35.5698474)    5.640000
# 1175382         POINT (139.6714914 35.5700268)    5.600000
#
# [1175383 rows x 6 columns]

# %%
edge_data = pd.read_csv("data/leftover_edges_v1.csv")
edge_data
# Out:
# /Users/s_araki/.pyenv/versions/3.6.5/envs/geoanalysis/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (4,5) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                 id      roadType roadName  oneWay speedLimit roadWidth  \
# 0          4848943  unclassified      NaN       1         10        10
# 1          4848943  unclassified      NaN       1         10        10
# 2          4848943  unclassified      NaN       1         10        10
# 3          4848943  unclassified      NaN       1         10        10
# 4          4848943  unclassified      NaN       1         10        10
# ...            ...           ...      ...     ...        ...       ...
# 3281768  812728992   residential      NaN       0          6         4
# 3281769  812728992   residential      NaN       0          6         4
# 3281770  812728998   residential      NaN       0          6         4
# 3281771  812728998   residential      NaN       0          6         4
# 3281772  812729001   residential      NaN       0          6         4
#
#          driveSpeed      source      target
# 0                10    31254395  6114579097
# 1                10  6114579097  1105125598
# 2                10  1105125598  1105125100
# 3                10  1105125100  1105125490
# 4                10  1105125490  1105125313
# ...             ...         ...         ...
# 3281768           6  2030079963  7591153650
# 3281769           6  7591153650  7591153651
# 3281770           6  3724132549  3724132548
# 3281771           6  3724132548  3724132547
# 3281772           6  7591165588  7591165589
#
# [3281773 rows x 9 columns]

# %%
# Main coverage
min_lon = 139.2019327633228
min_lat = 35.12569127247789
max_lon = 140.4100021566109
max_lat = 36.10592212339746

# Filter nodes
filter_cond = (node_data.lon > min_lon) & (node_data.lon < max_lon) & (node_data.lat > min_lat) & (node_data.lat < max_lat)
node_data = node_data.loc[filter_cond]

# Filter edges
node_set = set(node_data.id)
edge_data = edge_data.loc[edge_data.source.map(lambda s: s in node_set) & edge_data.target.map(lambda t: t in node_set)]

# %%
node_data = pd.read_csv("data/filtered-nodeData-TokyoArea-v5.csv")
# node_data.iloc[:, 1:].to_csv("data/filtered-nodeData-TokyoArea-v5.csv", index=False)

# %%
link_data = pd.read_csv("data/filtered-linkData-TokyoArea-v5.csv")
# link_data.to_csv("data/filtered-linkData-TokyoArea-v5.csv", index=False)
# Out:
# /Users/s_araki/.pyenv/versions/3.6.5/envs/geoanalysis/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (5) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
graph_gen = DirectedRoadGraphGenerator(version=5)
graph_gen.load_graph("data/roadNetwork-Directed-TokyoArea-v5.json", full_name=False)

# %%
G = graph_gen.graph
list(G.nodes(data=True))[:5], list(G.edges(data=True))[:5]
# Out:
# ([(31254395,
#    {'lat': 35.6698425,
#     'lon': 139.77472450000002,
#     'thisPoint': 'POINT (139.7747245 35.6698425)',
#     'elevation': 3.009999990463257,
#     'modality': 'road'}),
#   (6114579097,
#    {'lat': 35.6698176,
#     'lon': 139.7747877,
#     'thisPoint': 'POINT (139.7747877 35.6698176)',
#     'elevation': 2.740000009536743,
#     'modality': 'road'}),
#   (1105125598,
#    {'lat': 35.66968660000001,
#     'lon': 139.7751197,
#     'thisPoint': 'POINT (139.7751197 35.66968660000001)',
#     'elevation': 2.009999990463257,
#     'modality': 'road'}),
#   (1105125100,
#    {'lat': 35.669650299999994,
#     'lon': 139.7751501,
#     'thisPoint': 'POINT (139.7751501 35.66965029999999)',
#     'elevation': 1.7899999618530271,
#     'modality': 'road'}),
#   (1105125490,
#    {'lat': 35.669593,
#     'lon': 139.7751478,
#     'thisPoint': 'POINT (139.7751478 35.669593)',
#     'elevation': 1.7899999618530271,
#     'modality': 'road'})],
#  [(31254395,
#    6114579097,
#    {'roadType': 'unclassified',
#     'roadName': '',
#     'oneWay': 1,
#     'speedLimit': 10.0,
#     'roadWidth': 10.0,
#     'driveSpeed': 10,
#     'capacity': 500,
#     'numLanes': 1,
#     'modality': 'road',
#     'x1': 139.77472450000002,
#     'y1': 35.6698425,
#     'x2': 139.7747877,
#     'y2': 35.6698176,
#     'distance': 0,
#     'timeWeight': 0.0}),
#   (6114579097,
#    1105125598,
#    {'roadType': 'unclassified',
#     'roadName': '',
#     'oneWay': 1,
#     'speedLimit': 10.0,
#     'roadWidth': 10.0,
#     'driveSpeed': 10,
#     'capacity': 500,
#     'numLanes': 1,
#     'modality': 'road',
#     'x1': 139.7747877,
#     'y1': 35.6698176,
#     'x2': 139.7751197,
#     'y2': 35.66968660000001,
#     'distance': 0,
#     'timeWeight': 0.0}),
#   (1105125598,
#    1105125100,
#    {'roadType': 'unclassified',
#     'roadName': '',
#     'oneWay': 1,
#     'speedLimit': 10.0,
#     'roadWidth': 10.0,
#     'driveSpeed': 10,
#     'capacity': 500,
#     'numLanes': 1,
#     'modality': 'road',
#     'x1': 139.7751197,
#     'y1': 35.66968660000001,
#     'x2': 139.7751501,
#     'y2': 35.669650299999994,
#     'distance': 0,
#     'timeWeight': 0.0}),
#   (1105125100,
#    1105125490,
#    {'roadType': 'unclassified',
#     'roadName': '',
#     'oneWay': 1,
#     'speedLimit': 10.0,
#     'roadWidth': 10.0,
#     'driveSpeed': 10,
#     'capacity': 500,
#     'numLanes': 1,
#     'modality': 'road',
#     'x1': 139.7751501,
#     'y1': 35.669650299999994,
#     'x2': 139.7751478,
#     'y2': 35.669593,
#     'distance': 0,
#     'timeWeight': 0.0}),
#   (1105125490,
#    1105125313,
#    {'roadType': 'unclassified',
#     'roadName': '',
#     'oneWay': 1,
#     'speedLimit': 10.0,
#     'roadWidth': 10.0,
#     'driveSpeed': 10,
#     'capacity': 500,
#     'numLanes': 1,
#     'modality': 'road',
#     'x1': 139.7751478,
#     'y1': 35.669593,
#     'x2': 139.774943,
#     'y2': 35.6690545,
#     'distance': 0,
#     'timeWeight': 0.0})])

# %%
node_data.isnull().sum()
# Out:
# id           0
# lat          0
# lon          0
# thisPoint    0
# elevation    0
# dtype: int64

# %%
filename = "data/roadNetwork-Directed-TokyoArea-v5.json"
with open(filename, encoding='utf-8-sig') as f:
    js_graph = json.load(f)

# %%
links = pd.DataFrame(js_graph['links'])
nodes = pd.DataFrame(js_graph['nodes'])

# %%
check_map = keplergl.KeplerGl(height=400, data={"links": links, "nodes": nodes})
check_map.save_to_html(file_name="leftover_map.html")
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# Map saved to leftover_map.html!

# %%
originalLinkData = pd.read_csv("data/elevationLinkData-TokyoArea-v4.csv")
originalLinkData
# Out:
#                id  roadType    roadName  oneWay  speedLimit  roadWidth  \
# 0         4847506  motorway  首都高速11号台場線       1          80       21.0
# 1         4847506  motorway  首都高速11号台場線       1          80       21.0
# 2         4847506  motorway  首都高速11号台場線       1          80       21.0
# 3         4847506  motorway  首都高速11号台場線       1          80       21.0
# 4         4847506  motorway  首都高速11号台場線       1          80       21.0
# ...           ...       ...         ...     ...         ...        ...
# 910716  812570409   primary        厚木街道       0          30        9.0
# 910717  812570409   primary        厚木街道       0          30        9.0
# 910718  812570409   primary        厚木街道       0          30        9.0
# 910719  812570409   primary        厚木街道       0          30        9.0
# 910720  812570410   primary        厚木街道       0          30        9.0
#
#         driveSpeed      source      target  elevationGain
# 0               60    31236733   621545916          -0.49
# 1               60   621545916   621545917          -0.16
# 2               60   621545917    31236732          -0.42
# 3               60    31236732  1832774251          -0.03
# 4               60  1832774251  1832774248           0.00
# ...            ...         ...         ...            ...
# 910716           5  1565442394  7570072604            NaN
# 910717           5  7570072604  1565442396            NaN
# 910718           5  1565442396  7570072605            NaN
# 910719           5  7570072605  7309294738            NaN
# 910720           5  1565442295  7589639359            NaN
#
# [910721 rows x 10 columns]

# %%
filename = "data/roadNetwork-Directed-TokyoArea-with-elevation.json"
with open(filename, encoding='utf-8-sig') as f:
    js_graph = json.load(f)

# %%
thick_links = pd.DataFrame(js_graph['links'])

# %%
overall_map = keplergl.KeplerGl(height=400, data={"small_roads": links, "large_roads": thick_links})
overall_map.save_to_html(file_name="overall_map.html")
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# Map saved to overall_map.html!

# %%
thick_links.roadType.unique(), links.roadType.unique()
# Out:
# (array(['motorway', 'motorway_link', 'tertiary', 'tertiary_link',
#         'primary', 'secondary', 'trunk', 'primary_link', 'secondary_link',
#         'trunk_link', 'road'], dtype=object),
#  array(['unclassified', 'residential', 'pedestrian', 'living_street'],
#        dtype=object))

# %%
savepoint = pd.read_csv("savepoint_linkElevationData.csv")
savepoint.elevationGain.isnull().sum() / savepoint.shape[0]
# Out:
# /Users/s_araki/.pyenv/versions/3.6.5/envs/geoanalysis/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (5) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# 0.5193948126531692

# %%
len(thick_links.columns), len(links.columns)
# Out:
# (18, 17)

# %%
thick_links = thick_links.drop(columns='elevationGain')
thick_links.columns
# Out:
# Index(['roadType', 'roadName', 'oneWay', 'speedLimit', 'roadWidth',
#        'driveSpeed', 'capacity', 'numLanes', 'modality', 'x1', 'y1', 'x2',
#        'y2', 'distance', 'timeWeight', 'source', 'target'],
#       dtype='object')

# %%
overall_links = pd.concat([links, thick_links])
overall_links
# Out:
#              roadType roadName  oneWay  speedLimit roadWidth  driveSpeed  \
# 0        unclassified                1        10.0        10          10
# 1        unclassified                1        10.0        10          10
# 2        unclassified                1        10.0        10          10
# 3        unclassified                1        10.0        10          10
# 4        unclassified                1        10.0        10          10
# ...               ...      ...     ...         ...       ...         ...
# 1595788       primary     厚木街道       0        30.0         9           5
# 1595789       primary     厚木街道       0        30.0         9           5
# 1595790       primary     厚木街道       0        30.0         9           5
# 1595791       primary     厚木街道       0        30.0         9           5
# 1595792       primary     厚木街道       0        30.0         9           5
#
#              source      target  capacity  numLanes modality          x1  \
# 0          31254395  6114579097       500         1     road  139.774725
# 1        6114579097  1105125598       500         1     road  139.774788
# 2        1105125598  1105125100       500         1     road  139.775120
# 3        1105125100  1105125490       500         1     road  139.775150
# 4        1105125490  1105125313       500         1     road  139.775148
# ...             ...         ...       ...       ...      ...         ...
# 1595788  7570072604  1565442394      8000         2     road  139.487006
# 1595789  1565442396  7570072605      8000         2     road  139.487354
# 1595790  1565442396  7570072604      8000         2     road  139.487283
# 1595791  7570072605  7309294738      8000         2     road  139.487421
# 1595792  7570072605  1565442396      8000         2     road  139.487354
#
#                 y1          x2         y2  distance  timeWeight
# 0        35.669843  139.774788  35.669818         0         0.0
# 1        35.669818  139.775120  35.669687         0         0.0
# 2        35.669687  139.775150  35.669650         0         0.0
# 3        35.669650  139.775148  35.669593         0         0.0
# 4        35.669593  139.774943  35.669055         0         0.0
# ...            ...         ...        ...       ...         ...
# 1595788  35.466292  139.487283  35.466309         0         0.0
# 1595789  35.466313  139.487421  35.466315         0         0.0
# 1595790  35.466309  139.487354  35.466313         0         0.0
# 1595791  35.466315  139.487489  35.466318         0         0.0
# 1595792  35.466313  139.487421  35.466315         0         0.0
#
# [3623708 rows x 17 columns]

# %%
overall_links.isnull().sum() / overall_links.shape[0]
# Out:
# roadType      0.0
# roadName      0.0
# oneWay        0.0
# speedLimit    0.0
# roadWidth     0.0
# driveSpeed    0.0
# source        0.0
# target        0.0
# capacity      0.0
# numLanes      0.0
# modality      0.0
# x1            0.0
# y1            0.0
# x2            0.0
# y2            0.0
# distance      0.0
# timeWeight    0.0
# dtype: float64

# %%
filter_cond_source = (thick_links.y1 > min_lat) & (thick_links.y1 < max_lat) & (thick_links.x1> min_lon) & (thick_links.x1 < max_lon)
filter_cond_target = (thick_links.y2 > min_lat) & (thick_links.y2 < max_lat) & (thick_links.x2 > min_lon) & (thick_links.x2 < max_lon)
filtered_thick_links = thick_links.loc[filter_cond_source & filter_cond_target]

# %%
overall_links = pd.concat([links, filtered_thick_links])

# %%
overall_links.to_csv("data/kepler_viz_data.csv", index=False)

# %%
elevationLinkData = pd.read_csv("data/filtered-elevationLinkData-TokyoArea-v5.csv")

# %%
elevationLinkData.isnull().sum()/elevationLinkData.shape[0]
# Out:
# id               0.000000
# roadType         0.000000
# roadName         0.976103
# oneWay           0.000000
# speedLimit       0.000000
# roadWidth        0.000000
# driveSpeed       0.000000
# source           0.000000
# target           0.000000
# elevationGain    0.000000
# dtype: float64

# %%
filename = "data/roadNetwork-Directed-TokyoArea-with-elevation-v5.json"
with open(filename, encoding='utf-8-sig') as f:
    js_graph = json.load(f)

# %%
list(js_graph['links'])[0], list(js_graph['nodes'])[0]
# Out:
# ({'roadType': 'unclassified',
#   'roadName': '',
#   'oneWay': 1,
#   'speedLimit': 10.0,
#   'roadWidth': 10.0,
#   'driveSpeed': 10,
#   'elevationGain': -0.2699999809265137,
#   'capacity': 500,
#   'numLanes': 1,
#   'modality': 'road',
#   'x1': 139.77472450000002,
#   'y1': 35.6698425,
#   'x2': 139.7747877,
#   'y2': 35.6698176,
#   'distance': 0,
#   'timeWeight': 0.0,
#   'source': 31254395,
#   'target': 6114579097},
#  {'lat': 35.6698425,
#   'lon': 139.77472450000002,
#   'thisPoint': 'POINT (139.7747245 35.6698425)',
#   'elevation': 3.009999990463257,
#   'modality': 'road',
#   'id': 31254395})

# %%
elevation_test = pd.DataFrame(js_graph['links'])

# %%
elevation_test.isnull().sum() / elevation_test.shape[0]
# Out:
# roadType         0.000000
# roadName         0.000000
# oneWay           0.000000
# speedLimit       0.000000
# roadWidth        0.000000
# driveSpeed       0.000000
# elevationGain    0.475369
# capacity         0.000000
# numLanes         0.000000
# modality         0.000000
# x1               0.000000
# y1               0.000000
# x2               0.000000
# y2               0.000000
# distance         0.000000
# timeWeight       0.000000
# source           0.000000
# target           0.000000
# dtype: float64

# %%
node_set1 = set([(lat, lon) for lat, lon in zip(elevation_test.y1, elevation_test.x1)])
node_set2 = set([(lat, lon) for lat, lon in zip(elevation_test.y2, elevation_test.x2)])
link_node_set = node_set1 | node_set2
len(link_node_set)
# Out:
# 972801

# %%
len(js_graph['nodes'])
# Out:
# 972814

# %%
large_elevation_links = pd.read_csv("data/elevationLinkData-TokyoArea-v4.csv")
large_elevation_links.roadType.unique()
# Out:
# array(['motorway', 'motorway_link', 'tertiary', 'primary', 'secondary',
#        'trunk', 'tertiary_link', 'trunk_link', 'primary_link',
#        'secondary_link', 'road'], dtype=object)

# %%
large_elevation_links.isnull().sum() / large_elevation_links.shape[0]
# Out:
# id               0.000000
# roadType         0.000000
# roadName         0.491654
# oneWay           0.000000
# speedLimit       0.000000
# roadWidth        0.000000
# driveSpeed       0.000000
# source           0.000000
# target           0.000000
# elevationGain    0.640390
# dtype: float64

# %%
filename = "data/roadNetwork-Directed-TokyoArea-v4.json"
with open(filename, encoding='utf-8-sig') as f:
    js_graph_v4 = json.load(f)

# %%
old_links = pd.DataFrame(js_graph_v4['links'])
old_links.isnull().sum() / old_links.shape[0]
# Out:
# roadType      0.0
# roadName      0.0
# oneWay        0.0
# speedLimit    0.0
# roadWidth     0.0
# driveSpeed    0.0
# source        0.0
# target        0.0
# capacity      0.0
# numLanes      0.0
# modality      0.0
# x1            0.0
# y1            0.0
# x2            0.0
# y2            0.0
# distance      0.0
# timeWeight    0.0
# dtype: float64

# %%
filtered_nodes = pd.DataFrame(js_graph['nodes'])

# %%
filtered_nodes.isnull().sum()
# Out:
# lat          0
# lon          0
# thisPoint    0
# elevation    0
# modality     0
# id           0
# dtype: int64

# %%
len(set(link_data.source) | set(link_data.target)), node_data.shape[0]
# Out:
# (972814, 1175383)

# %%
node_data.isnull().sum()
# Out:
# id           0
# lat          0
# lon          0
# thisPoint    0
# elevation    0
# dtype: int64

# %%
node_set = set(node_data.id)
len(node_set), node_data.shape[0]
# Out:
# (1175383, 1175383)

# %%
link_data.source.map(lambda s: s in node_set).all()
# Out:
# True

# %%
link_data.target.map(lambda t: t in node_set).all()
# Out:
# True

# %%
node_data
# Out:
#                  id        lat         lon  \
# 0        1456908236  35.608371  139.239738
# 1        1456908266  35.608469  139.241025
# 2        1456908343  35.608457  139.241306
# 3        1456908374  35.608478  139.241423
# 4        1456908461  35.608547  139.241728
# ...             ...        ...         ...
# 1175378  6502211476  35.571015  139.671924
# 1175379  6502211477  35.571014  139.671329
# 1175380  6502211688  35.570163  139.672337
# 1175381  6502211693  35.569847  139.671568
# 1175382  6502211701  35.570027  139.671491
#
#                                      thisPoint   elevation
# 0               POINT (139.2397382 35.6083708)  415.190002
# 1               POINT (139.2410253 35.6084687)  393.260010
# 2               POINT (139.2413057 35.6084568)  388.769989
# 3               POINT (139.2414228 35.6084781)  386.750000
# 4        POINT (139.2417278 35.60854699999999)  379.260010
# ...                                        ...         ...
# 1175378         POINT (139.6719244 35.5710154)    7.800000
# 1175379  POINT (139.6713289 35.57101420000001)    5.350000
# 1175380  POINT (139.6723373 35.57016289999999)    7.670000
# 1175381         POINT (139.6715677 35.5698474)    5.640000
# 1175382         POINT (139.6714914 35.5700268)    5.600000
#
# [1175383 rows x 5 columns]

# %%
filename = "data/roadNetwork-Directed-TokyoArea-with-elevation-v5.json"
with open(filename, encoding='utf-8-sig') as f:
    js_graph_v5 = json.load(f)

# %%
new_link_data = pd.DataFrame(js_graph_v5['links'])

# %%
new_link_data
# Out:
#              roadType roadName  oneWay  speedLimit roadWidth  driveSpeed  \
# 0        unclassified                1        10.0        10          10
# 1        unclassified                1        10.0        10          10
# 2        unclassified                1        10.0        10          10
# 3        unclassified                1        10.0        10          10
# 4        unclassified                1        10.0        10          10
# ...               ...      ...     ...         ...       ...         ...
# 2027910   residential                0         6.0         4           6
# 2027911   residential                0         6.0         4           6
# 2027912   residential                0         6.0         4           6
# 2027913   residential                0         6.0         4           6
# 2027914   residential                0         6.0         4           6
#
#              source      target  capacity  numLanes modality          x1  \
# 0          31254395  6114579097       500         1     road  139.774725
# 1        6114579097  1105125598       500         1     road  139.774788
# 2        1105125598  1105125100       500         1     road  139.775120
# 3        1105125100  1105125490       500         1     road  139.775150
# 4        1105125490  1105125313       500         1     road  139.775148
# ...             ...         ...       ...       ...      ...         ...
# 2027910  7590138379  7590138378       500         1     road  139.571120
# 2027911  7590140392  1391658116       500         1     road  139.567870
# 2027912  7590140394  7590140393       500         1     road  139.565425
# 2027913  7590140393  1615202001       500         1     road  139.565562
# 2027914  7590140393  7590140394       500         1     road  139.565425
#
#                 y1          x2         y2  distance  timeWeight  elevationGain
# 0        35.669843  139.774788  35.669818         0         0.0      -0.270000
# 1        35.669818  139.775120  35.669687         0         0.0      -0.730000
# 2        35.669687  139.775150  35.669650         0         0.0      -0.220000
# 3        35.669650  139.775148  35.669593         0         0.0       0.000000
# 4        35.669593  139.774943  35.669055         0         0.0      -0.380000
# ...            ...         ...        ...       ...         ...            ...
# 2027910  35.509055  139.571403  35.508881         0         0.0       7.880001
# 2027911  35.506318  139.567525  35.506309         0         0.0            NaN
# 2027912  35.508689  139.565562  35.508780         0         0.0      -1.269999
# 2027913  35.508780  139.565608  35.508829         0         0.0       0.000000
# 2027914  35.508689  139.565562  35.508780         0         0.0            NaN
#
# [2027915 rows x 18 columns]

# %%
new_link_data.loc[new_link_data.elevationGain.isnull()]
# Out:
#              roadType roadName  oneWay  speedLimit roadWidth  driveSpeed  \
# 40       unclassified                0        10.0        10          10
# 49       unclassified                0        10.0        10          10
# 51       unclassified                0        10.0        10          10
# 54       unclassified                0        10.0        10          10
# 56       unclassified                0        10.0        10          10
# ...               ...      ...     ...         ...       ...         ...
# 2027906   residential                0         6.0         4           6
# 2027908   residential                0         6.0         4           6
# 2027909   residential                0         6.0         4           6
# 2027911   residential                0         6.0         4           6
# 2027914   residential                0         6.0         4           6
#
#              source      target  capacity  numLanes modality          x1  \
# 40         35926496    35926493       500         1     road  139.782301
# 49         35930919    35930918       500         1     road  139.760529
# 51         35930915    35930919       500         1     road  139.761934
# 54         35932470    35932472       500         1     road  139.770388
# 56       2896895382    35932470       500         1     road  139.770272
# ...             ...         ...       ...       ...      ...         ...
# 2027906  7589504712  7589504713       500         1     road  139.564984
# 2027908  7589504794  7589504795       500         1     road  139.561113
# 2027909  7589504793  7589504794       500         1     road  139.561247
# 2027911  7590140392  1391658116       500         1     road  139.567870
# 2027914  7590140393  7590140394       500         1     road  139.565425
#
#                 y1          x2         y2  distance  timeWeight  elevationGain
# 40       35.556638  139.782247  35.556608         0         0.0            NaN
# 49       35.573737  139.761934  35.573729         0         0.0            NaN
# 51       35.573729  139.761928  35.572530         0         0.0            NaN
# 54       35.571289  139.770272  35.571295         0         0.0            NaN
# 56       35.571295  139.770131  35.571296         0         0.0            NaN
# ...            ...         ...        ...       ...         ...            ...
# 2027906  35.505776  139.565178  35.505695         0         0.0            NaN
# 2027908  35.505531  139.561247  35.505664         0         0.0            NaN
# 2027909  35.505664  139.561379  35.505771         0         0.0            NaN
# 2027911  35.506318  139.567525  35.506309         0         0.0            NaN
# 2027914  35.508689  139.565562  35.508780         0         0.0            NaN
#
# [964007 rows x 18 columns]

# %%
source_id = 7590140392
target_id = 1391658116
source_elevation = node_data.loc[node_data.id == source_id].elevation.values[0]
target_elevation = node_data.loc[node_data.id == target_id].elevation.values[0]
target_elevation - source_elevation
# Out:
# -0.9699993133544922

# %%
G = nx.json_graph.node_link_graph(js_graph_v5, directed=True, multigraph=False)

# %%
G.edges[source_id, target_id]
# Out:
# {'roadType': 'residential',
#  'roadName': '',
#  'oneWay': 0,
#  'speedLimit': 6.0,
#  'roadWidth': 4.0,
#  'driveSpeed': 6,
#  'x1': 139.5678703,
#  'y1': 35.5063176,
#  'x2': 139.567525,
#  'y2': 35.506309,
#  'distance': 0,
#  'timeWeight': 0.0,
#  'modality': 'road',
#  'capacity': 500,
#  'numLanes': 1}

# %%
new_link_data.shape[0]
# Out:
# 2027915

# %%
nodes_from_links = set(new_link_data.source) | set(new_link_data.target)

# %%
node_set = set(pd.read_csv("data/filtered-nodeData-TokyoArea-v5.csv").id)

# %%
len(nodes_from_links & node_set)
# Out:
# 972814

# %%
def calculate_gain(row):
    if np.isnan(row.elevationGain):
        sourceHeight = node_data.loc[node_data.id == row.source].elevation.values[0]
        targetHeight = node_data.loc[node_data.id == row.target].elevation.values[0]
        print(f"{targetHeight - sourceHeight}")
        return targetHeight - sourceHeight
    else:
        return row.elevationGain

# %%
for i in range(new_link_data.shape[0]):
    elevationGain = new_link_data.loc[i, 'elevationGain']
    if np.isnan(elevationGain):
        row = new_link_data.loc[i, ['source', 'target']]
        sourceHeight = node_data.loc[node_data.id == row.source].elevation.values[0]
        targetHeight = node_data.loc[node_data.id == row.target].elevation.values[0]
        new_link_data.loc[i, 'elevationGain'] = targetHeight - sourceHeight
        if i % 10000 == 0:
            print(f"{i}th row: {targetHeight - sourceHeight}")
    if i % 10000 == 0:
        print(f"{i/964007*100}% processed!")

# new_link_data.loc[:, 'elevationGain'] = new_link_data.apply(calculate_gain, axis=1)
# Out:
# 0.0% processed!
# 10000th row: -0.05000305175782671
# 1.0373368658111404% processed!
# 2.0746737316222807% processed!
# 3.112010597433421% processed!
# 4.1493474632445615% processed!
# 50000th row: -0.40000152587890625
# 5.186684329055701% processed!
# 6.224021194866842% processed!
# 7.261358060677983% processed!
# 8.298694926489123% processed!
# 9.336031792300263% processed!
# 100000th row: -0.09000015258789773
# 10.373368658111403% processed!
# 110000th row: 0.0
# 11.410705523922545% processed!
# 12.448042389733684% processed!
# 13.485379255544824% processed!
# 14.522716121355966% processed!
# 15.560052987167106% processed!
# 16.597389852978246% processed!
# 170000th row: -0.059999942779541016
# 17.634726718789388% processed!
# 180000th row: -0.030002593994126414
# 18.672063584600526% processed!
# 190000th row: -1.3600006103515696
# 19.709400450411668% processed!
# 20.746737316222806% processed!
# 210000th row: -0.019999980926513672
# 21.784074182033947% processed!
# 220000th row: -0.7899999618530273
# 22.82141104784509% processed!
# 230000th row: 0.0
# 23.858747913656227% processed!
# 24.89608477946737% processed!
# 25.93342164527851% processed!
# 26.97075851108965% processed!
# 270000th row: 0.0
# 28.008095376900787% processed!
# 29.045432242711932% processed!
# 30.08276910852307% processed!
# 300000th row: 0.02000045776367898
# 31.120105974334212% processed!
# 310000th row: 0.43000030517578836
# 32.15744284014535% processed!
# 33.19477970595649% processed!
# 34.232116571767634% processed!
# 35.269453437578775% processed!
# 36.30679030338991% processed!
# 37.34412716920105% processed!
# 38.38146403501219% processed!
# 39.418800900823335% processed!
# 40.45613776663448% processed!
# 400000th row: 0.0
# 41.49347463244561% processed!
# 410000th row: -0.12999725341796875
# 42.53081149825675% processed!
# 420000th row: -0.07999992370605469
# 43.568148364067895% processed!
# 44.60548522987904% processed!
# 45.64282209569018% processed!
# 450000th row: 0.18000030517578125
# 46.68015896150132% processed!
# 47.717495827312455% processed!
# 48.754832693123596% processed!
# 49.79216955893474% processed!
# 490000th row: 2.6899986267089773
# 50.82950642474587% processed!
# 500000th row: 0.06000137329102273
# 51.86684329055702% processed!
# 52.90418015636816% processed!
# 520000th row: -0.10000228881835227
# 53.9415170221793% processed!
# 530000th row: -0.600006103515625
# 54.97885388799044% processed!
# 56.016190753801574% processed!
# 57.05352761961272% processed!
# 560000th row: -0.010000109672547053
# 58.090864485423864% processed!
# 59.128201351235% processed!
# 580000th row: 0.8000030517578125
# 60.16553821704614% processed!
# 61.202875082857275% processed!
# 600000th row: -0.5500030517578125
# 62.240211948668424% processed!
# 610000th row: -0.12999725341798296
# 63.277548814479566% processed!
# 64.3148856802907% processed!
# 630000th row: 0.019999980926513672
# 65.35222254610184% processed!
# 640000th row: 0.279998779296875
# 66.38955941191298% processed!
# 650000th row: -0.19000244140625
# 67.42689627772413% processed!
# 660000th row: 0.0
# 68.46423314353527% processed!
# 670000th row: -3.2900009155273438
# 69.50157000934641% processed!
# 680000th row: -0.21999740600585938
# 70.53890687515755% processed!
# 690000th row: -1.3800048828124716
# 71.57624374096868% processed!
# 700000th row: 1.30999755859375
# 72.61358060677982% processed!
# 710000th row: -0.04000091552735796
# 73.65091747259098% processed!
# 74.6882543384021% processed!
# 75.72559120421325% processed!
# 76.76292807002439% processed!
# 77.80026493583553% processed!
# 760000th row: -0.04000091552734375
# 78.83760180164667% processed!
# 770000th row: 0.0
# 79.87493866745781% processed!
# 80.91227553326895% processed!
# 81.94961239908008% processed!
# 800000th row: 0.630000114440918
# 82.98694926489122% processed!
# 810000th row: 0.17000198364258523
# 84.02428613070238% processed!
# 85.0616229965135% processed!
# 86.09895986232465% processed!
# 87.13629672813579% processed!
# 88.17363359394693% processed!
# 89.21097045975807% processed!
# 90.24830732556921% processed!
# 91.28564419138036% processed!
# 890000th row: 0.05000114440917258
# 92.32298105719148% processed!
# 900000th row: 0.26000213623046875
# 93.36031792300264% processed!
# 94.39765478881378% processed!
# 95.43499165462491% processed!
# 96.47232852043605% processed!
# 97.50966538624719% processed!
# 98.54700225205833% processed!
# 960000th row: 0.0
# 99.58433911786948% processed!
# 100.62167598368062% processed!
# 980000th row: 0.0
# 101.65901284949175% processed!
# 102.6963497153029% processed!
# 103.73368658111404% processed!
# 104.77102344692517% processed!
# 105.80836031273633% processed!
# 1030000th row: -0.2200012207031392
# 106.84569717854745% processed!
# 107.8830340443586% processed!
# 1050000th row: 0.07999998331069946
# 108.92037091016975% processed!
# 1060000th row: 0.47000122070312145
# 109.95770777598088% processed!
# 110.99504464179202% processed!
# 112.03238150760315% processed!
# 1090000th row: 0.09999847412109375
# 113.0697183734143% processed!
# 1100000th row: -1.5
# 114.10705523922545% processed!
# 1110000th row: -0.32999992370605113
# 115.14439210503657% processed!
# 116.18172897084773% processed!
# 1130000th row: 0.3800010681152344
# 117.21906583665887% processed!
# 118.25640270247% processed!
# 1150000th row: -0.279998779296875
# 119.29373956828115% processed!
# 1160000th row: -0.1100006103515625
# 120.33107643409228% processed!
# 121.36841329990342% processed!
# 122.40575016571455% processed!
# 123.4430870315257% processed!
# 124.48042389733685% processed!
# 1210000th row: 0.06999969482421875
# 125.51776076314798% processed!
# 1220000th row: -0.27000045776366477
# 126.55509762895913% processed!
# 1230000th row: -0.05000019073486328
# 127.59243449477027% processed!
# 128.6297713605814% processed!
# 1250000th row: 0.20000076293944957
# 129.66710822639257% processed!
# 130.70444509220368% processed!
# 1270000th row: -0.1999998092651376
# 131.74178195801483% processed!
# 1280000th row: 0.0
# 132.77911882382597% processed!
# 1290000th row: 0.17000007629393465
# 133.8164556896371% processed!
# 1300000th row: 0.8000001907348637
# 134.85379255544825% processed!
# 135.8911294212594% processed!
# 136.92846628707053% processed!
# 1330000th row: -0.10000002384185791
# 137.96580315288168% processed!
# 1340000th row: 0.6000003814697301
# 139.00314001869282% processed!
# 140.04047688450396% processed!
# 141.0778137503151% processed!
# 142.11515061612624% processed!
# 143.15248748193736% processed!
# 1390000th row: -0.09000015258788707
# 144.18982434774853% processed!
# 145.22716121355964% processed!
# 146.26449807937078% processed!
# 147.30183494518195% processed!
# 148.33917181099307% processed!
# 1440000th row: -0.2999992370605469
# 149.3765086768042% processed!
# 1450000th row: 0.3999938964844034
# 150.41384554261538% processed!
# 1460000th row: -0.17999982833862305
# 151.4511824084265% processed!
# 1470000th row: -0.039999961853026456
# 152.48851927423763% processed!
# 1480000th row: -1.2700004577636719
# 153.52585614004877% processed!
# 1490000th row: -2.790000915527351
# 154.56319300585992% processed!
# 1500000th row: 0.8800010681152273
# 155.60052987167106% processed!
# 156.6378667374822% processed!
# 157.67520360329334% processed!
# 158.71254046910448% processed!
# 159.74987733491562% processed!
# 160.78721420072677% processed!
# 1560000th row: -0.350000143051147
# 161.8245510665379% processed!
# 162.86188793234905% processed!
# 163.89922479816016% processed!
# 1590000th row: -0.6000003814697266
# 164.93656166397133% processed!
# 165.97389852978245% processed!
# 1610000th row: -0.06000518798828125
# 167.0112353955936% processed!
# 168.04857226140476% processed!
# 1630000th row: -0.15999603271484375
# 169.08590912721587% processed!
# 170.123245993027% processed!
# 1650000th row: 0.0
# 171.16058285883818% processed!
# 172.1979197246493% processed!
# 1670000th row: 0.1900005340576154
# 173.23525659046044% processed!
# 1680000th row: -0.1100006103515625
# 174.27259345627158% processed!
# 175.30993032208272% processed!
# 176.34726718789386% processed!
# 1710000th row: -0.10000038146972656
# 177.384604053705% processed!
# 1720000th row: -0.02999997138976962
# 178.42194091951615% processed!
# 1730000th row: -2.1399993896484375
# 179.4592777853273% processed!
# 180.49661465113843% processed!
# 1750000th row: -0.07999992370605113
# 181.53395151694957% processed!
# 1760000th row: -0.4599990844726598
# 182.5712883827607% processed!
# 183.60862524857185% processed!
# 1780000th row: -0.15999984741210938
# 184.64596211438297% processed!
# 185.68329898019414% processed!
# 1800000th row: 0.09000015258788352
# 186.72063584600528% processed!
# 187.7579727118164% processed!
# 188.79530957762756% processed!
# 1830000th row: 0.9599990844726562
# 189.8326464434387% processed!
# 1840000th row: 0.07999992370605469
# 190.86998330924982% processed!
# 1850000th row: -0.55999755859375
# 191.907320175061% processed!
# 192.9446570408721% processed!
# 1870000th row: 0.279998779296875
# 193.98199390668324% processed!
# 195.01933077249438% processed!
# 196.05666763830553% processed!
# 1900000th row: -0.05999755859375
# 197.09400450411667% processed!
# 198.1313413699278% processed!
# 1920000th row: 0.3299999237060547
# 199.16867823573895% processed!
# 1930000th row: -2.4800014495849503
# 200.20601510155007% processed!
# 1940000th row: 0.16000032424926847
# 201.24335196736124% processed!
# 202.28068883317238% processed!
# 1960000th row: 0.43000030517578125
# 203.3180256989835% processed!
# 204.35536256479466% processed!
# 1980000th row: 0.19999980926513672
# 205.3926994306058% processed!
# 1990000th row: -0.059999465942386365
# 206.43003629641692% processed!
# 2000000th row: -1.5
# 207.46737316222809% processed!
# 208.50471002803923% processed!
# 209.54204689385034% processed!

# %%
new_link_data.isnull().sum()
# Out:
# roadType              0
# roadName              0
# oneWay                0
# speedLimit            0
# roadWidth             0
# driveSpeed            0
# source                0
# target                0
# capacity              0
# numLanes              0
# modality              0
# x1                    0
# y1                    0
# x2                    0
# y2                    0
# distance              0
# timeWeight            0
# elevationGain    964007
# dtype: int64

# %%
old_links.shape
# Out:
# (1595793, 17)

# %%
new_link_data
